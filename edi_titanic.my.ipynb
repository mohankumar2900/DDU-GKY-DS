# %%
import pandas as pd
import numpy as  np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(columns='PassengerId',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df.sort_values(by='Age')
df.value_counts('Pclass')
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
plt.figure(figsize=(6,5))
plt.xlabel('Pclass')
plt.ylabel('Age')
sns.lineplot(data=df,x='Pclass',y='Age')
plt.show()

# %%
pd.crosstab(df.Pclass,df.Embarked,margins=True)
# Out:
# Embarked    C   Q    S  All
# Pclass
# 1          85   2  127  214
# 2          17   3  164  184
# 3          66  72  353  491
# All       168  77  644  889

# %%
df.drop(columns='pclass1',inplace=True)
df.drop(columns='pclass1.1',inplace=True)

# %%
pclass1=df.query("Sex=='male'& Pclass==1")
pclass2=df.query("Sex=='male'& Pclass==2")
pclass3=df.query("Sex=='male'& Pclass==3")
pclass1
pclass1
pclass2
# Out:
#      Survived  Pclass                           Name   Sex   Age  SibSp  \
# 17          1       2   Williams, Mr. Charles Eugene  male   NaN      0
# 20          0       2           Fynney, Mr. Joseph J  male  35.0      0
# 21          1       2          Beesley, Mr. Lawrence  male  34.0      0
# 33          0       2          Wheadon, Mr. Edward H  male  66.0      0
# 70          0       2     Jenkin, Mr. Stephen Curnow  male  32.0      0
# ..        ...     ...                            ...   ...   ...    ...
# 848         0       2              Harper, Rev. John  male  28.0      0
# 861         0       2    Giles, Mr. Frederick Edward  male  21.0      1
# 864         0       2         Gill, Mr. John William  male  24.0      0
# 883         0       2  Banfield, Mr. Frederick James  male  28.0      0
# 886         0       2          Montvila, Rev. Juozas  male  27.0      0
#
#      Parch            Ticket  Fare Cabin Embarked
# 17       0            244373  13.0   NaN        S
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'pclass1', 'pclass1.1'],
#       dtype='object')

# %%
df01 = df[['Name','Pclass', 'Sex', 'Age','Survived','Embarked']]

# %%
df01
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0
# 4                             Allen, Mr. William Henry       3    male  35.0
# ..                                                 ...     ...     ...   ...
# 886                              Montvila, Rev. Juozas       2    male  27.0
# 887                       Graham, Miss. Margaret Edith       1  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"       3  female   NaN
# 889                              Behr, Mr. Karl Howell       1    male  26.0
# 890                                Dooley, Mr. Patrick       3    male  32.0
#
#      Survived Embarked
# ...

# %% [markdown]
# #  PCLASS 1 ONLY SURVIVED LIST AGE WISE

# %%
pc1=df01.query("Sex=='male' & Pclass==1 & Survived==1")
pc1.reset_index(drop=True,inplace=True)
pc1.sort_values(by='Age')
pc1
# Out:
#                                              Name  Pclass   Sex    Age  \
# 0                    Sloper, Mr. William Thompson       1  male  28.00
# 1                               Woolner, Mr. Hugh       1  male    NaN
# 2                 Greenfield, Mr. William Bertram       1  male  23.00
# 3   Romaine, Mr. Charles Hallace ("Mr C Rolmane")       1  male  45.00
# 4                                Blank, Mr. Henry       1  male  40.00
# 5                    Hoyt, Mr. Frederick Maxfield       1  male  38.00
# 6                   Beckwith, Mr. Richard Leonard       1  male  37.00
# 7                           Saalfeld, Mr. Adolphe       1  male    NaN
# 8                  Allison, Master. Hudson Trevor       1  male   0.92
# 9                     Harder, Mr. George Achilles       1  male  25.00
# 10                     Carter, Mr. William Ernest       1  male  36.00
# 11      Bjornstrom-Steffansson, Mr. Mauritz Hakan       1  male  28.00
# ...

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df,x='Embarked',y='Age',color='red',hue='Sex')
plt.title('---1st_PCLASS--AGE-Embarked--SEX--GRAPH')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df,x='Embarked',y='Fare',color='red',hue='Sex')
plt.title('---1st_PCLASS--Fare-Embarked--SEX--GRAPH')
plt.show()

# %%
import math
x=math.sqrt(64)
x
# Out:
# 8.0

# %%
import math
l=[1, 2, 3, 4, 5]
x=math.fsum(l)
a=math.prod(l)
a
# Out:
# 120

# %%
#y=math.gcd(3,6)


b=math.radians(180)
b
# Out:
# 3.141592653589793
